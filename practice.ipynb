# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Encountered a start tag:", tag)

    def handle_endtag(self, tag):
        print("Encountered an end tag :", tag)

    def handle_data(self, data):
        print("Encountered some data  :", data)

parser = MyHTMLParser()
parser.feed('<html><head><title>Test</title></head>'
            '<body><h1>Parse me!</h1></body></html>')
# Out:
# Encountered a start tag: html
# Encountered a start tag: head
# Encountered a start tag: title
# Encountered some data  : Test
# Encountered an end tag : title
# Encountered an end tag : head
# Encountered a start tag: body
# Encountered a start tag: h1
# Encountered some data  : Parse me!
# Encountered an end tag : h1
# Encountered an end tag : body
# Encountered an end tag : html

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
html_text=requests.get("https://www.sacnilk.com/articles/entertainment/box_office/Pathan_2022_Box_Office_Collection_Day_Wise_Worldwide?hl=en")

# %%
html_text=html_text.text

# %%
html_text
# Out:
# '\n<!doctype html>\n<html lang="en" prefix="og: https://ogp.me/ns#">\n<head>\n<meta charset="UTF-8"/>\n<style>.async-hide{opacity:0!important}</style>\n<script>(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;h.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;})(window,document.documentElement,\'async-hide\',\'dataLayer\',4000,{\'GTM-55K4HK9\':true});</script>\n<script>(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');ga(\'create\',\'UA-111362017-1\',\'auto\');ga(\'require\',\'GTM-55K4HK9\');ga(\'send\',\'pageview\');</script>\n<script>window._taboola=window._taboola||[];_taboola.push({article:\'au
# ...

# %%
html_soup=BeautifulSoup(html_text,"html.parser")

# %%
html_soup.find_all("td")
# Out:
# [<td class="td">Day 1 [1st Wednesday]</td>,
#  <td class="td">₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] </td>,
#  <td class="td">-</td>,
#  <td class="td">Day 2 [1st Thursday]</td>,
#  <td class="td">₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] </td>,
#  <td class="td">23.68%</td>,
#  <td class="td">Day 3 [1st Friday]</td>,
#  <td class="td">₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] </td>,
#  <td class="td">-44.33%</td>,
#  <td class="td">Day 4 [1st Saturday]</td>,
#  <td class="td">₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] </td>,
#  <td class="td">35.67%</td>,
#  <td class="td">Day 5 [1st Sunday]</td>,
#  <td class="td">₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] </td>,
#  <td class="td">14.08%</td>,
#  <td class="td">Day 6 [1st Monday]</td>,
#  <td class="td">₹ 26.5 Cr [Hi: 25.5 Cr ; Te: 0.65 Cr; Ta: 0.35 Cr] </td>,
#  <td class="td">-56.38%</td>,
#  <td class="td">Day 7 [1st Tuesday]</td>,
# ...

# %%
html_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <style>.async-hide{opacity:0!important}</style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;})(window,document.documentElement,'async-hide','dataLayer',4000,{'GTM-55K4HK9':true});</script>
# <script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');ga('create','UA-111362017-1','auto');ga('require','GTM-55K4HK9');ga('send','pageview');</script>
# ...

# %%
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
wikipedia=requests.get("https://en.wikipedia.org/wiki/Shivaji").text

# %%
wikipedia
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Shivaji - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited
# ...

# %%
wikipedia_soup=BeautifulSoup(wikipedia)

# %%
wikipedia_soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Shivaji - Wikipedia</title>
# ...

# %%
wikipedia_soup.find_all('table',class_="infobox vcard")
# Out:
# [<table class="infobox vcard"><tbody><tr><th class="infobox-above fn" colspan="2" style="background-color: #cbe; font-size: 125%">Shivaji I</th></tr><tr><td class="infobox-subheader" colspan="2"><i>Shakakarta<sup class="reference" id="cite_ref-FOOTNOTESardesai1957222_1-0"><a href="#cite_note-FOOTNOTESardesai1957222-1">[1]</a></sup><br/><a href="/wiki/Defender_of_the_Faith#Other" title="Defender of the Faith">Haindava Dharmoddharak</a><sup class="reference" id="cite_ref-Chandra1982_2-0"><a href="#cite_note-Chandra1982-2">[2]</a></sup><br/></i></td></tr><tr><td class="infobox-image photo" colspan="2"><a class="image" href="/wiki/File:Shivaji_British_Museum.jpg"><img alt="Shivaji British Museum.jpg" data-file-height="2500" data-file-width="1775" decoding="async" height="310" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Shivaji_British_Museum.jpg/220px-Shivaji_British_Museum.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Shivaji_British_Museum.jpg/330px-Shiv
# ...

# %%
box_office=html_soup.find_all("tr")

# %%
box_office
# Out:
# [<tr><th class="th">Day</th><th class="th">India Net Collection</th>
#  <th class="th">Change(+/-)</th></tr>,
#  <tr>
#  <td class="td">Day 1 [1st Wednesday]</td>
#  <td class="td">₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] </td>
#  <td class="td">-</td>
#  </tr>,
#  <tr>
#  <td class="td">Day 2 [1st Thursday]</td>
#  <td class="td">₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] </td>
#  <td class="td">23.68%</td>
#  </tr>,
#  <tr>
#  <td class="td">Day 3 [1st Friday]</td>
#  <td class="td">₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] </td>
#  <td class="td">-44.33%</td>
#  </tr>,
#  <tr>
#  <td class="td">Day 4 [1st Saturday]</td>
#  <td class="td">₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] </td>
#  <td class="td">35.67%</td>
#  </tr>,
#  <tr>
#  <td class="td">Day 5 [1st Sunday]</td>
#  <td class="td">₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] </td>
#  <td class="td">14.08%</td>
#  </tr>,
#  <tr>
#  <td class="td">Day 6 [1st Monday]</td>
# ...

# %%
for row in box_office:
#     print(row)
    for column in row.find_all("td"):
        print("cloumn name:",column.text)
#         print("column after break\n\n\n\n\n")
    print("row after break\n\n\n\n\n")
# Out:
# row after break
#
#
#
#
#
# cloumn name: Day 1 [1st Wednesday]
# cloumn name: ₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr]
# cloumn name: -
# row after break
#
#
#
#
#
# cloumn name: Day 2 [1st Thursday]
# cloumn name: ₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr]
# cloumn name: 23.68%
# row after break
#
#
#
#
#
# cloumn name: Day 3 [1st Friday]
# cloumn name: ₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr]
# cloumn name: -44.33%
# row after break
#
#
#
#
#
# cloumn name: Day 4 [1st Saturday]
# cloumn name: ₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr]
# cloumn name: 35.67%
# row after break
#
#
#
#
#
# cloumn name: Day 5 [1st Sunday]
# cloumn name: ₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr]
# cloumn name: 14.08%
# row after break
#
#
#
#
#
# cloumn name: Day 6 [1st Monday]
# cloumn name: ₹ 26.5 Cr [Hi: 25.5 Cr ; Te: 0.65 Cr; Ta: 0.35 Cr]
# cloumn name: -56.38%
# row after break
#
#
#
#
#
# cloumn name: Day 7 [1st Tuesday]
# ...

# %%
box_office_table=html_soup.table

# %%
box_office_table
# Out:
# <table class="table"><tr><th class="th">Day</th><th class="th">India Net Collection</th>
# <th class="th">Change(+/-)</th></tr><tr>
# <td class="td">Day 1 [1st Wednesday]</td>
# <td class="td">₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] </td>
# <td class="td">-</td>
# </tr><tr>
# <td class="td">Day 2 [1st Thursday]</td>
# <td class="td">₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] </td>
# <td class="td">23.68%</td>
# </tr><tr>
# <td class="td">Day 3 [1st Friday]</td>
# <td class="td">₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] </td>
# <td class="td">-44.33%</td>
# </tr><tr>
# <td class="td">Day 4 [1st Saturday]</td>
# <td class="td">₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] </td>
# <td class="td">35.67%</td>
# </tr><tr>
# <td class="td">Day 5 [1st Sunday]</td>
# <td class="td">₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] </td>
# <td class="td">14.08%</td>
# </tr><tr>
# <td class="td">Day 6 [1st Monday]</td>
# ...

# %%
count=0
for row in box_office_table:
    print(row)
    count+=1
    print("after row\n\n")
# Out:
# <tr><th class="th">Day</th><th class="th">India Net Collection</th>
# <th class="th">Change(+/-)</th></tr>
# after row
#
#
# <tr>
# <td class="td">Day 1 [1st Wednesday]</td>
# <td class="td">₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] </td>
# <td class="td">-</td>
# </tr>
# after row
#
#
# <tr>
# <td class="td">Day 2 [1st Thursday]</td>
# <td class="td">₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] </td>
# <td class="td">23.68%</td>
# </tr>
# after row
#
#
# <tr>
# <td class="td">Day 3 [1st Friday]</td>
# <td class="td">₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] </td>
# <td class="td">-44.33%</td>
# </tr>
# after row
#
#
# <tr>
# <td class="td">Day 4 [1st Saturday]</td>
# <td class="td">₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] </td>
# <td class="td">35.67%</td>
# </tr>
# after row
#
#
# <tr>
# <td class="td">Day 5 [1st Sunday]</td>
# <td class="td">₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] </td>
# <td class="td">14.08%</td>
# </tr>
# after row
#
#
# <tr>
# ...

# %%
count
# Out:
# 61

# %%
count_row=0
# count_column=0
for row in box_office_table:
    count_column=0
    for column in row:
        
#         print(type(column))
#         print(count_column)
#         print("column break \n\n\n")
        count_column+=1
    print("row type",type(row))
# Out:
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# row type <class 'bs4.element.Tag'>
# ...

# %%
x=type(box_office_table)

# %%
if x=="bs4.element.Tag":
    print("ok")

# %%
x=str(type(box_office_table))

# %%
# Out:
# "<class 'bs4.element.Tag'>"

# %%
type(box_office_table) is bs4.element.Tag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_41362/3442009953.py in <module>
# ----> 1 type(box_office_table) is bs4.element.Tag
#
# NameError: name 'bs4' is not defined

# %%
isinstance(box_office_table,bs4.element.Tag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_41362/3421118425.py in <module>
# ----> 1 isinstance(box_office_table,bs4.element.Tag)
#
# NameError: name 'bs4' is not defined

# %%
main_dict=[]

# %%
count_row=0
head=[]

for row in box_office_table:
         if str(type(row))=="<class 'bs4.element.Tag'>":
                sub_dict={}
                if count_row==0:
                    for column in row:
                        if str(type(column))=="<class 'bs4.element.Tag'>":
            #                 print("headings:",column.text)
                            head.append(column.text)




                else:
                        count_column=0
                        for column in row:
                            if str(type(column))=="<class 'bs4.element.Tag'>":
            #                     print("column name only:",column.text)
                                sub_dict[head[count_column]]=column.text
                                count_column+=1

                        print(sub_dict)
                        main_dict.append(sub_dict)
                count_row+=1

                print("\n\n\n\n")
# Out:
# {'Day': 'Day 1 [1st Wednesday]', 'India Net Collection': '₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] ', 'Change(+/-)': '-'}
#
#
#
#
#
# {'Day': 'Day 2 [1st Thursday]', 'India Net Collection': '₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] ', 'Change(+/-)': '23.68%'}
#
#
#
#
#
# {'Day': 'Day 3 [1st Friday]', 'India Net Collection': '₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] ', 'Change(+/-)': '-44.33%'}
#
#
#
#
#
# {'Day': 'Day 4 [1st Saturday]', 'India Net Collection': '₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] ', 'Change(+/-)': '35.67%'}
#
#
#
#
#
# {'Day': 'Day 5 [1st Sunday]', 'India Net Collection': '₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] ', 'Change(+/-)': '14.08%'}
#
#
#
#
#
# {'Day': 'Day 6 [1st Monday]', 'India Net Collection': '₹ 26.5 Cr [Hi: 25.5 Cr ; Te: 0.65 Cr; Ta: 0.35 Cr] ', 'Change(+/-)': '-56.38%'}
#
#
#
#
#
# ...

# %%
head[0]
# Out:
# 'Day'

# %%
dict_={}

# %%
main_dict
# Out:
# {'Day': 'Total',
#  'India Net Collection': '₹ 540.76 Cr [Hi: 522.2 Cr ; Te: 12.76 Cr; Ta: 5.8 Cr]',
#  'Change(+/-)': '-'}

# %%
main_dict
# Out:
# [{'Day': 'Day 1 [1st Wednesday]',
#   'India Net Collection': '₹ 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] ',
#   'Change(+/-)': '-'},
#  {'Day': 'Day 2 [1st Thursday]',
#   'India Net Collection': '₹ 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] ',
#   'Change(+/-)': '23.68%'},
#  {'Day': 'Day 3 [1st Friday]',
#   'India Net Collection': '₹ 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] ',
#   'Change(+/-)': '-44.33%'},
#  {'Day': 'Day 4 [1st Saturday]',
#   'India Net Collection': '₹ 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] ',
#   'Change(+/-)': '35.67%'},
#  {'Day': 'Day 5 [1st Sunday]',
#   'India Net Collection': '₹ 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] ',
#   'Change(+/-)': '14.08%'},
#  {'Day': 'Day 6 [1st Monday]',
#   'India Net Collection': '₹ 26.5 Cr [Hi: 25.5 Cr ; Te: 0.65 Cr; Ta: 0.35 Cr] ',
#   'Change(+/-)': '-56.38%'},
#  {'Day': 'Day 7 [1st Tuesday]',
#   'India Net Collection': '₹ 23 Cr [Hi: 22 Cr ; Te: 0.6 Cr; Ta: 0.4 Cr] ',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_41362/3602038890.py in <module>
#       1 with open("index.txt",mode="w") as file:
# ----> 2     file.write(main_dict)
#
# TypeError: write() argument must be str, not list

# %%
import json

# %%
json_object=json.dumps(main_dict,indent=4)

# %%
json_object
# Out:
# '[\n    {\n        "Day": "Day 1 [1st Wednesday]",\n        "India Net Collection": "\\u20b9 57 Cr [Hi: 55 Cr ; Te: 1.5 Cr; Ta: 0.5 Cr] ",\n        "Change(+/-)": "-"\n    },\n    {\n        "Day": "Day 2 [1st Thursday]",\n        "India Net Collection": "\\u20b9 70.5 Cr [Hi: 68 Cr ; Te: 1.75 Cr; Ta: 0.75 Cr] ",\n        "Change(+/-)": "23.68%"\n    },\n    {\n        "Day": "Day 3 [1st Friday]",\n        "India Net Collection": "\\u20b9 39.25 Cr [Hi: 38 Cr ; Te: 0.85 Cr; Ta: 0.4 Cr] ",\n        "Change(+/-)": "-44.33%"\n    },\n    {\n        "Day": "Day 4 [1st Saturday]",\n        "India Net Collection": "\\u20b9 53.25 Cr [Hi: 51.5 Cr ; Te: 1.25 Cr; Ta: 0.5 Cr] ",\n        "Change(+/-)": "35.67%"\n    },\n    {\n        "Day": "Day 5 [1st Sunday]",\n        "India Net Collection": "\\u20b9 60.75 Cr [Hi: 58.5 Cr ; Te: 1.5 Cr; Ta: 0.75 Cr] ",\n        "Change(+/-)": "14.08%"\n    },\n    {\n        "Day": "Day 6 [1st Monday]",\n        "India Net Collection": "\\u20b9 26.5 Cr [Hi: 25
# ...

# %%
with open("box_office_table.json",mode="w") as file:
    file.write(json_object)

# %%
<div class="elementor-widget-container"> <p>Formed in 1939, The Marvel Comics Group is one of the big three American comic publishers alongside <a href="https://www.telltalesonline.com/30095/dc-comics-facts/">DC Comics</a> and Dark Horse. So it’s no surprise that since their 1961 rebirth with the Fantastic Four, they have become synonymous with American superheroes.</p> <p>With an enormous roster that really sells the idea of a superhero community (particularly the downtrodden mutant population), we look back at over 50 years of the most famous Universe. Here’s a list of the most popular Marvel characters and their powers (in no particular order)…</p><div id="AdThrive_Content_1_desktop" class="adthrive-ad adthrive-content adthrive-content-1 adthrive-ad-cls" style="min-height: 250px;" data-google-query-id="CJnOkeie6v0CFdcR1QodXBIDsw"><div id="google_ads_iframe_/18190176,25813836/AdThrive_Content_1/5f0ee98114feb52e354c4c15_0__container__" style="border: 0pt none; display: inline-block; width: 336px; height: 280px;"><iframe frameborder="0" src="https://946d6ff387809ab034f695288add9ed7.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" id="google_ads_iframe_/18190176,25813836/AdThrive_Content_1/5f0ee98114feb52e354c4c15_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="336" height="280" data-is-safeframe="true" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" allow="attribution-reporting" role="region" aria-label="Advertisement" tabindex="0" data-google-container-id="3" style="border: 0px; vertical-align: bottom; width: 336px;" data-load-complete="true"></iframe></div></div> <h2 id="captain-america">Captain America</h2> <p><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Strength, agility, stamina, healing ability,&nbsp;expert&nbsp;tactician, martial artist, indestructible shield.</span></p> <p class="nitro-offscreen">The First Avenger by age, Captain America actually joined the team in their early years after he broke out of a block of ice from the Arctic. Before becoming Captain America, Steve Rogers was weak and sickly, given treatment that granted him superhuman condition. His extraordinary bones and muscles make him capable of breaking wood and steel with a single hit, while his shield makes him resistant to destruction. With incredible lung capacity, Cap has high endurance and is a skilled martial artist.</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1941<br><b>How he got his Powers:</b><span style="font-weight:400;"> Injected with Super-Soldier Serum.</span><b><br>Weapons: </b><span style="font-weight:400;">Vibranium shield<br></span><b>Did You Know? </b>The fighting style Captain America uses is called “Jeet Kune Do”, inspired by Bruce Lee! Learn more <a href="https://www.telltalesonline.com/41323/captain-america-facts/">facts about Captain America</a>!</p> <p class="has-text-align-center nitro-offscreen"><iframe width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/CTq3G9KMdb8/embed/" class="instagram lazyloaded"></iframe></p><div id="AdThrive_Content_2_desktop" class="adthrive-ad adthrive-content adthrive-content-2 adthrive-ad-cls" style="min-height: 250px;" data-google-query-id="CPO63-ie6v0CFQ1FaAod2hENmg"><div id="google_ads_iframe_/18190176,25813836/AdThrive_Content_2/5f0ee98114feb52e354c4c15_0__container__" style="border: 0pt none; display: inline-block; width: 336px; height: 280px;"><iframe frameborder="0" src="https://946d6ff387809ab034f695288add9ed7.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" id="google_ads_iframe_/18190176,25813836/AdThrive_Content_2/5f0ee98114feb52e354c4c15_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="336" height="280" data-is-safeframe="true" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" allow="attribution-reporting" role="region" aria-label="Advertisement" tabindex="0" data-google-container-id
embed/" class="instagram-v nitro-lazy"></iframe></p><div id="AdThrive_Content_4_desktop" class="adthrive-ad adthrive-content adthrive-content-4 adthrive-ad-cls" style="min-height: 250px;" data-google-query-id="CPmFtOie6v0CFYiErAIdcaIKhA"><div id="google_ads_iframe_/18190176,25813836/AdThrive_Content_4/5f0ee98114feb52e354c4c15_0__container__" style="border: 0pt none; display: inline-block; width: 336px; height: 280px;"><iframe frameborder="0" src="https://946d6ff387809ab034f695288add9ed7.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" id="google_ads_iframe_/18190176,25813836/AdThrive_Content_4/5f0ee98114feb52e354c4c15_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="336" height="280" data-is-safeframe="true" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" allow="attribution-reporting" role="region" aria-label="Advertisement" tabindex="0" data-google-container-id="5" style="border: 0px; vertical-align: bottom; width: 336px;" data-load-complete="true"></iframe></div></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="groot" class="nitro-offscreen">Groot</h2> <p style="font-size:18px;" class="nitro-offscreen"><em><span style="color:#999;" class="has-inline-color">Superpowers</span></em>: Superhuman strength to lift and break; a durability of dense wood; ability to extend body, generate flowers, twigs and leaves; light generation; regenerative healing factor; talented combatant.&nbsp;</p> <p class="nitro-offscreen">This Marvel hero may act like a teen and lack the ability to speak, but that doesn’t make his super powers any less extraordinary. Groot, the Flora colossus (a tree-like humanoid being) and one of the Guardians of the Galaxy, has an array of abilities including superhuman strength, durability and a regenerative healing factor that makes him difficult to kill. With a biology made up of plant-like and wood tissues, Groot can regrow body parts and sustain any attack from shots and explosions. Groot also has the strength to break strong metals, extend his body to grow longer, and create a bulletproof shield with twigs.&nbsp;</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1960<br><strong>How he got his Powers: </strong>Born as a Flora colossus<br><strong>Weapons: </strong>His powers<br><strong>Did You Know? </strong>In the comics, Groot originally appeared as an invader of Earth, capturing humans for experimentation.&nbsp;</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/CJqRu4sMY2h/embed/" class="instagram-v nitro-lazy"></iframe></p><div id="AdThrive_Content_5_desktop" class="adthrive-ad adthrive-content adthrive-content-5 adthrive-ad-cls" style="min-height: 250px;" data-google-query-id="CLyNxeie6v0CFQXvaAodGwgFfQ"><div id="google_ads_iframe_/18190176,25813836/AdThrive_Content_5/5f0ee98114feb52e354c4c15_0__container__" style="border: 0pt none; display: inline-block; width: 336px; height: 280px;"><iframe frameborder="0" src="https://946d6ff387809ab034f695288add9ed7.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" id="google_ads_iframe_/18190176,25813836/AdThrive_Content_5/5f0ee98114feb52e354c4c15_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="336" height="280" data-is-safeframe="true" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" allow="attribution-reporting" role="region" aria-label="Advertisement" tabindex="0" data-google-container-id="7" style="border: 0px; vertical-align: bottom; width: 336px;" data-load-complete="true"></iframe></div></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="hawkeye" class="nitro-offscreen">Hawkeye</h2> <p style="font-size:18px;" class="nitro-offscreen"><em><span style="color:#999;" class="has-inline-color">Superpowers</span></em>: Marksmanship, assassin, marital artist, knife &amp; sword master and expert pilot.</p> <p class="nitro-offscreen">Clint Barton has been an Avenger and agent for S.H.I.E.L.D for a reason – his remarkable and out of this world talent in marksmanship. Not a ‘superhero’ per se, but more of a normal guy with the superhuman ability to fire arrows and bows with extreme precision and accuracy; Hawkeye has helped defeat multiple enemies with his fine skills. He has spectacular eyesight and hand-eye coordination, can fire multiple arrows in a few seconds, and directly hit small targets in far distances. Hawkeye is also a master assassin and excellent martial artist.&nbsp;</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1964<br
embed/" class="instagram-v nitro-lazy"></iframe></p><div id="AdThrive_Content_45_desktop" class="adthrive-ad adthrive-content adthrive-content-45 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="ant-man" class="nitro-offscreen">Ant-Man</h2> <p class="nitro-offscreen"><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Genius-level intellect, size-changing via Pym Particles, telepathic communication with insects, dimension-hopping.</span></p> <p class="nitro-offscreen">One of the first Avengers, Hank Pym is an eccentric genius who created Pym Particles, the exotic matter that can shrink and grow objects while retaining their proportionate strength. Taking on other names like Giant-Man, Goliath, Yellowjacket and even his own wife’s alias, The Wasp, he’s a bit unstable and prone to nervous breakdowns. That doesn’t take away his extraordinary abilities to shrink to the size of an ant, exceed in hand-to-hand combat, and grow to gigantic heights.</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1962<br><b>How he got his Powers: </b>Tested the Pym Particles serum on himself<b><br></b><b>Weapons: </b><span style="font-weight:400;">Stinger firearm</span><br><b>Did you Know? </b>Like Doctor Strange passes through multiverses, Ant-Man can travel through micro-versus – “tiny parallel dimensions”.</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/3PUwwML3d8/embed/" class="instagram nitro-lazy"></iframe></p><div id="AdThrive_Content_46_desktop" class="adthrive-ad adthrive-content adthrive-content-46 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="magneto" class="nitro-offscreen">Magneto</h2> <p class="nitro-offscreen"><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Control of magnetic forces, magnetism-based flight, can make telepathic commands.</span></p> <p class="nitro-offscreen">The Master of Magnetism, leader of the Brotherhood of Mutants, closest friend of Charles Exavier, and possibly the world’s second most massive hypocrite. It’s hard to not feel sorry for a guy who survived the Nazi death camps but explaining Eric Lehnsherr, is no small feat. Though he certainly doesn’t make it easy with his plan to supplant humans with mutants as the dominant species on Earth. With his power to control metal and manipulate magnetic forces, there’s no going near this guy. Heck, he apparently can use magnetism to “raise islands from ocean floors and move mountains”.</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1963<br><b>How he got his Powers: </b>Mutant-born<b><br>Weapons: </b>Helmet, powers<br><strong>Did You Know? </strong>Magneto has the power to move large asteroids and levitate a 30,000 ton nuclear submarine!</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/CMxkwNejdgr/embed/" class="instagram-v nitro-lazy"></iframe></p><div id="AdThrive_Content_47_desktop" class="adthrive-ad adthrive-content adthrive-content-47 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="jessica-jones" class="nitro-offscreen">Jessica Jones</h2> <p class="nitro-offscreen"><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Superhuman strength, flight, immunity to mind control.</span></p> <p class="nitro-offscreen">Vigilante private investigator, Jessica Jones is one of the fresher faces of Marvel’s roster. Gaining her powers when a military convoy of radioactive material collides with her parents’ car, she wakes up from a coma with superhuman abilities including strength, flight and the skill to block and control. She can push over a rooted tree, punch through the hood of a car, and can even resist mind control. Instead however, she fights crime as a detective. Those powers coming in handy for defense when cases go down some ugly roads.</p> <p class="nitro-offscreen"><strong>Year Created</strong>: 2001<br><b>How she got her Powers: </b><span style="font-weight:400;">Radioactive chemicals following car accident.<br></span><b>Weapons: </b><span style="font-weight:400;">Her talent/powers</span><br><strong>Did You Know? </strong>Jessica attended the same high school as Peter Parker and she even had a crush on him! Find out more <a href="https://www.telltalesonline.com/28915/marvel-facts/">cool superhero facts</a>!</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/BErfKZpSRH8/embed/" class="instagram nitro-lazy"></iframe></p><div id="AdThrive_Content_48_desktop" class="adthrive-ad adthrive-content adthrive-content-48 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="blade" class="nitro-offscreen">Blade</h2> <p class="nitro-offscreen"><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Strength, speed, reflexes, immune to vampire bites, master swordsman.</span></p> <p class="nitro-offscreen">Called “the Daywalker” by his blood-sucking foes, Blade is known across the world as a man with all the strengths of a vampire, none of the weaknesses and a natural immunity to vampire talents. He heals rapidly, is unaffected by daylight and is gifted with heightened senses including the ability to detect sounds that a regular human can’t, and “smell” supernatural creatures. He’s the ideal predator after the Van Helsings are gone.</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1973<br><span style="font-weight:400;"><strong>How he got his Powers:</strong> Mother was bitten by vampire during labor.<br><strong>Weapons</strong>: </span>Daggers, titanium, acid-etched swords, firearms<b><br></b><strong>Did You Know? </strong>Marvel’s first big hit is one of the only movies that doesn’t feature a Stan Lee cameo!</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/CFSaqRkBSkD/embed/" class="instagram-v nitro-lazy"></iframe></p><div id="AdThrive_Content_49_desktop" class="adthrive-ad adthrive-content adthrive-content-49 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="doctor-doom" class="nitro-offscreen">Doctor Doom</h2> <p class="nitro-offscreen"><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Superhuman strength, energy blasts, flight via rocket boots, inventor genius.</span></p> <p class="nitro-offscreen">T’Challa is not the only high-profile king moonlighting as a super-person. King of Latveria Victor, von Doom is a complex sort, he may blame absolutely everything wrong with his life on Reed Richards (which is frequently his downfall), but he’s also worked with some of the heroes. In particular, he has enlisted the help of Doctor Strange to rescue his mother from Mephisto’s realm. The Doctor considers him one of the “most powerful practitioners of sorcery” thanks to his great ability to emit mystical blasts and force-fields, as well as cast spells.</p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1962<br><b>How he got his Powers: </b>His mother’s Roma heritage<b><br>Weapons: </b>His powers<br><strong>Did You Know? </strong>In the comics, Doctor Doom has been depicted as one of the most intelligent humans in the Marvel Universe.</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/B0PN9oilOgS/embed/" class="instagram-v nitro-lazy"></iframe></p><div id="AdThrive_Content_50_desktop" class="adthrive-ad adthrive-content adthrive-content-50 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <h2 id="the-mandarin" class="nitro-offscreen">The Mandarin</h2> <p class="nitro-offscreen"><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Peak-level human condition, martial arts expert, 10 Rings of Power.</span></p> <p class="nitro-offscreen">Tony Stark’s greatest opponent is not a rival CEO like Obidiah Stane or the Russians trying to copy his work, but this 100-year-old Chinese aristocrat. Beyond a genius military mind, the Mandarin is an intellectual equal to Iron Man. He is technologically aided by the 10 Rings of Power alien technology he wears on each finger that through invention and practice, grant him numerous powers such as cryokinesis<span style="font-weight:400;">, </span>electrokinesis<span style="font-weight:400;">, the ability to emit </span>energy beams<span style="font-weight:400;"> and</span> blasts<span style="font-weight:400;">, levitation and mind control to say the least.&nbsp;</span></p> <p class="nitro-offscreen"><strong>Year Created:</strong> 1964<br><b>How got his Powers: </b>From the 10 Rings of Power<b><br>Weapons: </b>10&nbsp;Rings of Power<br><strong>Did You Know? </strong>His martial arts skills are so great, it is said The Mandarin can destroy Iron Man’s armor with his bare hands.</p> <p class="has-text-align-center nitro-offscreen"><iframe loading="lazy" width="612" height="710" frameborder="0" scrolling="no" nitro-lazy-src="//instagram.com/p/B0daeqOhDEC/embed/" class="instagram nitro-lazy"></iframe></p><div id="AdThrive_Content_51_desktop" class="adthrive-ad adthrive-content adthrive-content-51 adthrive-ad-cls" style="min-height: 250px;"></div> <hr class="wp-block-separator has-css-opacity nitro-offscreen"> <p class="nitro-offscreen">Now that you’ve scrolled through our list of Marvel heroes, who do you think has the strongest superpowers in the Marvel Universe?</p> <p class="nitro-offscreen">Is it Ghost Rider? How about the Hulk? Let us know in the comments below…</p> <p class="has-cyan-bluish-gray-color has-text-color nitro-offscreen" style="font-size:11px;"><span style="font-size:8pt;"><em>Information in this article has been sourced from Super Hero DB</em></span> <em>and Marvel Cinematic Universe Fandom</em>.</p> </div>

# %%
marvel=requests.get("https://www.telltalesonline.com/28598/popular-marvel-characters/").text

# %%
marvel
# Out:
# '403 - Forbidden | Access to this page is forbidden.\n'

# %%
marvel=open("../marvel.html",mode="r")

# %%
marvel_soup=BeautifulSoup(marvel)

# %%
marvel_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
marvel_soup.div(class_="elementor-element elementor-element-19057e6e elementor-widget-mobile__width-inherit elementor-widget__width-inherit elementor-widget elementor-widget-theme-post-content")
# Out:
# []

# %%
marvel_box=marvel_soup.find("div",class_="elementor-element elementor-element-19057e6e elementor-widget-mobile__width-inherit elementor-widget__width-inherit elementor-widget elementor-widget-theme-post-content")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_41362/2113596433.py in <module>
# ----> 1 type(marvel_box[0])
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getitem__(self, key)
#    1517         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518         and throws an exception if it's not there."""
# -> 1519         return self.attrs[key]
#    1520
#    1521     def __iter__(self):
#
# KeyError: 0

# %%
type(marvel_box)
# Out:
# bs4.element.Tag

# %%
marvel_box.find_all("h2")
# Out:
# [<h2 id="captain-america">Captain America</h2>,
#  <h2 id="black-panther">Black Panther</h2>,
#  <h2 id="killmonger">Killmonger</h2>,
#  <h2 id="groot">Groot</h2>,
#  <h2 id="hawkeye">Hawkeye</h2>,
#  <h2 id="black-widow">Black Widow</h2>,
#  <h2 id="the-winter-soldier">The Winter Soldier</h2>,
#  <h2 id="star-lord">Star-Lord</h2>,
#  <h2 id="wolverine">Wolverine</h2>,
#  <h2 id="iron-man">Iron Man</h2>,
#  <h2 id="ultron">Ultron</h2>,
#  <h2 id="scarlet-witch">Scarlet Witch</h2>,
#  <h2 id="vision">Vision</h2>,
#  <h2 id="iron-fist">Iron Fist</h2>,
#  <h2 id="hulk">Hulk</h2>,
#  <h2 id="spider-man">Spider-Man</h2>,
#  <h2 id="loki">Loki</h2>,
#  <h2 id="black-bolt">Black Bolt</h2>,
#  <h2 id="captain-marvel">Captain Marvel</h2>,
#  <h2 id="luke-cage">Luke Cage</h2>,
#  <h2 id="quicksilver">Quicksilver</h2>,
#  <h2 id="ghost-rider">Ghost Rider</h2>,
#  <h2 id="daredevil">Daredevil</h2>,
#  <h2 id="spider-woman">Spider-Woman</h2>,
#  <h2 id="silver-surfer">Silver Surfer</h2>,
# ...

# %%
marvel_superheroes=[]

# %%
super_hero={}
for hero in marvel_box.find_all("h2")

# %%
marvel_p=marvel_box.find_all("p")

# %%
type(marvel_p[0])
# Out:
# bs4.element.Tag

# %%
x=marvel_p[2]

# %%
if x.span:
    print("hii")
else:
    print("bye")
# Out:
# hii

# %%
marvel_p
# Out:
# [<p>Formed in 1939, The Marvel Comics Group is one of the big three American comic publishers alongside <a href="https://www.telltalesonline.com/30095/dc-comics-facts/">DC Comics</a> and Dark Horse. So it’s no surprise that since their 1961 rebirth with the Fantastic Four, they have become synonymous with American superheroes.</p>,
#  <p>With an enormous roster that really sells the idea of a superhero community (particularly the downtrodden mutant population), we look back at over 50 years of the most famous Universe. Here’s a list of the most popular Marvel characters and their powers (in no particular order)…</p>,
#  <p><span style="font-size:14pt;"><span style="color:#999;"><em>Superpowers</em></span>: Strength, agility, stamina, healing ability, expert tactician, martial artist, indestructible shield.</span></p>,
# ...

# %%
superpowers=[]

# %%
hero_name=marvel_box.find_all("h2")
for para in marvel_p[0:-1]:
    
        if para.span and para.span.em :
            print(para.span.text)
            superpowers.append(para.span.text)
        if para.em and para.em.span :
            superpowers.append(para.text)
# Out:
# Superpowers: Strength, agility, stamina, healing ability, expert tactician, martial artist, indestructible shield.
# Superpowers: Enhanced senses, superhuman condition, speed, martial artist, magical resistance, Vibranium-assisted outfit.
# Superpowers: Strength, expert tactician and manipulator, peak-level hunter, genius-level intellect.
# Superpowers: Energy blasts, superhuman strength, martial artist, speed, healing, stamina.
# Superpowers: Strength, flight via jet boots, master problem-solver, cybernetic enhancements, space travel, Element Gun projects air, earth, fire, water.
# Superpowers: Reflexes, agility, senses, retractable adamantium-plated bone claws, regeneration, indestructible skeleton.
# Superpowers: Genius-level intellect, multiple powered armor suits, ability to fly.
# Superpowers: Strength, speed, stamina, genius-level artificial intelligence, makes calculations with superhuman speed and accuracy, nigh indestructibility via adamantium bodies, flight.
# ...

# %%
superpowers
# Out:
# ['Superpowers: Strength, agility, stamina, healing ability,\xa0expert\xa0tactician, martial artist, indestructible shield.',
#  'Superpowers: Enhanced senses, superhuman condition, speed, martial artist, magical resistance, Vibranium-assisted outfit.',
#  'Superpowers: Strength, expert tactician and manipulator, peak-level hunter, genius-level intellect.',
#  'Superpowers: Superhuman strength to lift and break; a durability of dense wood; ability to extend body, generate flowers, twigs and leaves; light generation; regenerative healing factor; talented combatant.\xa0',
#  'Superpowers: Marksmanship, assassin, marital artist, knife & sword master and expert pilot.',
#  'Superpowers: Master spy & assassin, martial artist, armed combatant; skills in espionage, infiltration, disguise and deception, manipulation & hacking.\xa0',
#  'Superpowers: Energy blasts, superhuman strength, martial artist, speed, healing, stamina.',
# ...

# %%
main=[]
for i in range(len(superpowers)):
    main.append({"superheroname":hero_name[i].text,"superpowers":superpowers[i].replace("Superpowers:","")})
    
#     print(hero_name[i].text,superpowers[i])

# %%
main
# Out:
# [{'superheroname': 'Captain America',
#   'superpowers': ' Strength, agility, stamina, healing ability,\xa0expert\xa0tactician, martial artist, indestructible shield.'},
#  {'superheroname': 'Black Panther',
#   'superpowers': ' Enhanced senses, superhuman condition, speed, martial artist, magical resistance, Vibranium-assisted outfit.'},
#  {'superheroname': 'Killmonger',
#   'superpowers': ' Strength, expert tactician and manipulator, peak-level hunter, genius-level intellect.'},
#  {'superheroname': 'Groot',
#   'superpowers': ' Superhuman strength to lift and break; a durability of dense wood; ability to extend body, generate flowers, twigs and leaves; light generation; regenerative healing factor; talented combatant.\xa0'},
#  {'superheroname': 'Hawkeye',
#   'superpowers': ' Marksmanship, assassin, marital artist, knife & sword master and expert pilot.'},
#  {'superheroname': 'Black Widow',
# ...

# %%
marvel_json_object=json.dumps(main,indent=4)

# %%
with open("superhero.json",mode="w") as file:
    file.write(marvel_json_object)
